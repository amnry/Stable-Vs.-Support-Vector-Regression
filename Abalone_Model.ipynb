# %% [markdown]
# ### Data Processing

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
os.add_dll_directory('C:\Aorda\PSG\lib')
import psgpython as psg
import random
import yfinance as yf
# %matplotlib inline
from sklearn.svm import NuSVR
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
 
allowExternal = True
suppressMessages = False

# %%
alpha = .6
c = 10

# %% [markdown]
# ### NuSVR Implmentation

# %%
columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
abalone_data = pd.read_csv('Data/abalone.data', header = None, names = columns)
abalone_data['Sex'] = pd.Categorical(abalone_data['Sex'], categories=['I','M','F'], ordered=True)

y = abalone_data['Rings']                   #Dependent
X = abalone_data.drop(columns=['Rings'])    #Independent



abalone_preprocessor = ColumnTransformer(
    transformers = [
        ("num", StandardScaler(),['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight']),
        ("cat", OneHotEncoder(drop='first'), ['Sex']),
    ]
)

abalone_pipeline = Pipeline([
    ("preprocessor",abalone_preprocessor),
    ("svr", NuSVR(C=c, nu=1-alpha,gamma="auto",kernel='linear', tol=1e-7))

])

abalone_pipeline.fit(X,y)
abalone_svr = abalone_pipeline.named_steps['svr']
#X_transformed = abalone_pipeline.named_steps['preprocessor'].transform(X)
#coefficients = np.dot(abalone_svr.dual_coef_,abalone_svr.support_vectors_).flatten()
coefficients = abalone_svr.coef_.flatten()
intercept = abalone_svr.intercept_

coefficients
# Out:
# array([ 0.01180033,  0.92385042,  0.62961541,  3.8785749 , -3.84235663,
#        -1.08063668,  1.04415583, -0.63380008,  0.06901395])

# %% [markdown]
# ### PSG Implentation

# %%
columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
abalone_data = pd.read_csv('Data/abalone.data', header = None, names = columns)
abalone_data['Sex'] = pd.Categorical(abalone_data['Sex'], categories=['I','M','F'], ordered=True)

y = abalone_data['Rings']                   #Dependent
X = abalone_data.drop(columns=['Rings'])    #Independent\

abalone_preprocessor = ColumnTransformer(
    transformers = [
        ("num", StandardScaler(),['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight']),
        ("cat", OneHotEncoder(drop='first'), ['Sex']),
    ]
)

X_transformed = abalone_preprocessor.fit_transform(X)

# %%
N = X_transformed.shape[0]
regularization_term = 1/(2*c*N)

x1 = np.ones((N,1))
matrix_scenarios_body = np.column_stack((x1,X_transformed, y.values.reshape(-1,1)))
header = ["x%d" % (i) for i in range(1,matrix_scenarios_body.shape[1])]
matrix_scenarios = [header + ['scenario_benchmark'], matrix_scenarios_body]

quadratic_size = X_transformed.shape[1]+1
matrix_quadratic_body = np.zeros((quadratic_size,quadratic_size))
matrix_quadratic_body[1:,1:] = regularization_term
matrix_quadratic = [["x%d" % (i+1) for i in range(quadratic_size)], matrix_quadratic_body]

# %%
problem_name_p = "problem_abalone"
problem_statement_p = "minimize\n\
# %f" % (1-alpha) + "*cvar_risk(" + "%f" % (alpha) + ",abs(matrix_scenarios))\n\
+quadratic(matrix_quadratic)\n\
Value: \n\
var_risk(" + "%f" % (alpha) + ",abs(matrix_scenarios))\n\
Solver: van"
problem_dictionary_abalone = {'problem_name': problem_name_p, 
                             'problem_statement': problem_statement_p,
                             'matrix_scenarios': matrix_scenarios, 
                             'matrix_quadratic': matrix_quadratic}

# Optimization Output
res_primal = psg.psg_solver(problem_dictionary_abalone, allowExternal, suppressMessages)
# Out:
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
#       9.1% of scenarios is processed
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.514819248264E+01  Residual=0.000000000000E+00
# Ext.iteration=105  Objective=0.116083971704E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16083971704 [1.780351355229E-08]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.12, preprocessing_time = 0.01, solving_time = 0.03
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16083971704 [1.780351355229E-08]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.902069074337E+00
# Function: quadratic(matrix_quadratic) =  1.208730318205E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.421649510634E+00
# OK. Solver Finished

# %% [markdown]
# #### PSG/CVaR Regression Coefficients

# %%
coeff = res_primal['point_problem_1'][1][1:]
coeff
# Out:
# array([ 0.01001566,  0.9235053 ,  0.62587867,  3.9435627 , -3.87465006,
#        -1.10397277,  1.04142231, -0.63172853,  0.07084149])

# %% [markdown]
# #### NuSVR Coefficients

# %%
coefficients
# Out:
# array([ 0.01180033,  0.92385042,  0.62961541,  3.8785749 , -3.84235663,
#        -1.08063668,  1.04415583, -0.63380008,  0.06901395])

# %% [markdown]
# #### NnSVR Intercept

# %%
intercept
# Out:
# array([9.96343375])

# %% [markdown]
# #### PSG/CVaR Regression Intercept

# %%
res_primal['point_problem_1'][1][0]
# Out:
# 9.965103523524213

# %% [markdown]
# ### Data Splitting

# %%
columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
abalone_data = pd.read_csv('Data/abalone.data', header = None, names = columns)
abalone_data['Sex'] = pd.Categorical(abalone_data['Sex'], categories=['I','M','F'], ordered=True)

y = abalone_data['Rings']                   #Dependent
X = abalone_data.drop(columns=['Rings'])    #Independent



abalone_preprocessor = ColumnTransformer(
    transformers = [
        ("num", StandardScaler(),['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight']),
        ("cat", OneHotEncoder(drop='first'), ['Sex']),
    ]
)

abalone_pipeline = Pipeline([
    ("preprocessor",abalone_preprocessor),
    ("svr", NuSVR(C=c, nu=1-alpha,gamma="auto",kernel='linear', tol=1e-7))

])

svr_coeff_vec = []
svr_interp_vec = []
cvar_coeff_vec = []
cvar_interp_vec = []




for _ in range(1000):
    # Split the data into testing and training, then average over the coefficents
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5)

    abalone_pipeline.fit(X_train,y_train)
    abalone_svr = abalone_pipeline.named_steps['svr']
    #X_transformed = abalone_pipeline.named_steps['preprocessor'].transform(X)
    #coefficients = np.dot(abalone_svr.dual_coef_,abalone_svr.support_vectors_).flatten()
    coefficients = abalone_svr.coef_.flatten()
    intercept = abalone_svr.intercept_

    svr_coeff_vec.append(coefficients)
    svr_interp_vec.append(intercept)


    # PSG
    X_transformed = abalone_preprocessor.fit_transform(X_train)

    N = X_transformed.shape[0]
    regularization_term = 1/(2*c*N)

    x1 = np.ones((N,1))
    matrix_scenarios_body = np.column_stack((x1,X_transformed, y_train.values.reshape(-1,1)))
    header = ["x%d" % (i) for i in range(1,matrix_scenarios_body.shape[1])]
    matrix_scenarios = [header + ['scenario_benchmark'], matrix_scenarios_body]

    quadratic_size = X_transformed.shape[1]+1
    matrix_quadratic_body = np.zeros((quadratic_size,quadratic_size))
    matrix_quadratic_body[1:,1:] = regularization_term
    matrix_quadratic = [["x%d" % (i+1) for i in range(quadratic_size)], matrix_quadratic_body]

    problem_name_p = "problem_abalone"
    problem_statement_p = "minimize\n\
    # %f" % (1-alpha) + "*cvar_risk(" + "%f" % (alpha) + ",abs(matrix_scenarios))\n\
    +quadratic(matrix_quadratic)\n\
    Value: \n\
    var_risk(" + "%f" % (alpha) + ",abs(matrix_scenarios))\n\
    Solver: van"
    problem_dictionary_abalone = {'problem_name': problem_name_p, 
                                'problem_statement': problem_statement_p,
                                'matrix_scenarios': matrix_scenarios, 
                                'matrix_quadratic': matrix_quadratic}

    # Optimization Output
    res_primal = psg.psg_solver(problem_dictionary_abalone, allowExternal, suppressMessages)

    cvar_coeff_vec.append(res_primal['point_problem_1'][1][1:])
    cvar_interp_vec.append(res_primal['point_problem_1'][1][0])
# Out:
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.512260536398E+01  Residual=0.000000000000E+00
# Ext.iteration=112  Objective=0.113593375788E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.13593375788 [3.330062892104E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.13593375788 [3.330062892104E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.839780471013E+00
# Function: quadratic(matrix_quadratic) =  2.156946984950E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.349795603765E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.515900383142E+01  Residual=0.000000000000E+00
# Ext.iteration=110  Objective=0.116188469178E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16188469178 [3.582678598235E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16188469178 [3.582678598235E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.904665113789E+00
# Function: quadratic(matrix_quadratic) =  1.864626917912E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.456652008582E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.515852490421E+01  Residual=0.000000000000E+00
# Ext.iteration=158  Objective=0.113850264471E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.13850264471 [1.777000768755E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.11, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.13850264471 [1.777000768755E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.846177803456E+00
# Function: quadratic(matrix_quadratic) =  3.152332867467E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.384213658419E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.516714559387E+01  Residual=0.000000000000E+00
# Ext.iteration=95  Objective=0.117937957144E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.17937957144 [1.291872808729E-08]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.11, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.17937957144 [1.291872808729E-08]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.948414544075E+00
# Function: quadratic(matrix_quadratic) =  1.375381225363E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.438803765622E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.512021072797E+01  Residual=0.000000000000E+00
# Ext.iteration=111  Objective=0.114501213893E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.14501213893 [2.938405074815E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.14501213893 [2.938405074815E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.862477929849E+00
# Function: quadratic(matrix_quadratic) =  2.096699392295E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.436293409352E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.514415708812E+01  Residual=0.000000000000E+00
# Ext.iteration=113  Objective=0.116433312033E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16433312033 [4.462623603985E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16433312033 [4.462623603985E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.910773325765E+00
# Function: quadratic(matrix_quadratic) =  2.379002787062E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.419448325407E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.522078544061E+01  Residual=0.000000000000E+00
# Ext.iteration=108  Objective=0.118296120428E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.18296120428 [7.626876907807E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.18296120428 [7.626876907807E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.957359391169E+00
# Function: quadratic(matrix_quadratic) =  1.744780934447E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.447483875042E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.512739463602E+01  Residual=0.000000000000E+00
# Ext.iteration=97  Objective=0.114648777900E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.14648777900 [2.825850664578E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.12, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.14648777900 [2.825850664578E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.866189401693E+00
# Function: quadratic(matrix_quadratic) =  1.201832252257E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.453408154928E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.516283524904E+01  Residual=0.000000000000E+00
# Ext.iteration=123  Objective=0.115770130825E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.15770130825 [1.904454371982E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.15770130825 [1.904454371982E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.894170121570E+00
# Function: quadratic(matrix_quadratic) =  3.325961850816E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.463765946619E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.514750957854E+01  Residual=0.000000000000E+00
# Ext.iteration=113  Objective=0.114246386944E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.14246386944 [2.591260539475E-13]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.14246386944 [2.591260539475E-13]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.856119499301E+00
# Function: quadratic(matrix_quadratic) =  1.606972406806E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.366794789937E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.522892720307E+01  Residual=0.000000000000E+00
# Ext.iteration=110  Objective=0.120476203042E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.20476203042 [1.032463314843E-08]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.20476203042 [1.032463314843E-08]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  3.011799938963E+00
# Function: quadratic(matrix_quadratic) =  4.205483544059E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.447597939501E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.516475095785E+01  Residual=0.000000000000E+00
# Ext.iteration=133  Objective=0.116953055955E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16953055955 [1.549638195542E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16953055955 [1.549638195542E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.923775814455E+00
# Function: quadratic(matrix_quadratic) =  2.023377142807E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.433535584488E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.511015325670E+01  Residual=0.000000000000E+00
# Ext.iteration=122  Objective=0.117072127544E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.17072127544 [6.905587213168E-14]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.01
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.17072127544 [6.905587213168E-14]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.926755516993E+00
# Function: quadratic(matrix_quadratic) =  1.906864614449E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.411052477331E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.510871647510E+01  Residual=0.000000000000E+00
# Ext.iteration=104  Objective=0.114806648387E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.14806648387 [9.992007221626E-15]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.01
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.14806648387 [9.992007221626E-15]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.870124600704E+00
# Function: quadratic(matrix_quadratic) =  1.664358417072E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.393864305761E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.521216475096E+01  Residual=0.000000000000E+00
# Ext.iteration=109  Objective=0.119133523648E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.19133523648 [3.764411582452E-08]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.12, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.19133523648 [3.764411582452E-08]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.978307129552E+00
# Function: quadratic(matrix_quadratic) =  1.238465944746E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.454056596373E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.509386973180E+01  Residual=0.000000000000E+00
# Ext.iteration=121  Objective=0.114174688248E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.14174688248 [1.096143176227E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.14174688248 [1.096143176227E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.854335316591E+00
# Function: quadratic(matrix_quadratic) =  1.275583897063E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.407500188017E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.515134099617E+01  Residual=0.000000000000E+00
# Ext.iteration=127  Objective=0.116578398191E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16578398191 [4.114708573866E-12]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.11, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16578398191 [4.114708573866E-12]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.914387535451E+00
# Function: quadratic(matrix_quadratic) =  2.896772771269E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.417028614624E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.512404214559E+01  Residual=0.000000000000E+00
# Ext.iteration=96  Objective=0.116183381794E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16183381794 [3.461586572939E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16183381794 [3.461586572939E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.904517115313E+00
# Function: quadratic(matrix_quadratic) =  2.697181225724E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.419283349372E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.512931034483E+01  Residual=0.000000000000E+00
# Ext.iteration=100  Objective=0.114228084128E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.14228084128 [6.914468997365E-13]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.01
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.14228084128 [6.914468997365E-13]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.855640701318E+00
# Function: quadratic(matrix_quadratic) =  2.456075310956E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.391386752833E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.510632183908E+01  Residual=0.000000000000E+00
# Ext.iteration=118  Objective=0.112571096538E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.12571096538 [1.130764371027E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.12, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.12571096538 [1.130764371027E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.814191001565E+00
# Function: quadratic(matrix_quadratic) =  3.456475586537E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.379574823611E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.519013409962E+01  Residual=0.000000000000E+00
# Ext.iteration=117  Objective=0.117453996867E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.17453996867 [1.815114725190E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.01
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.17453996867 [1.815114725190E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.936256866076E+00
# Function: quadratic(matrix_quadratic) =  3.722223571978E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.459202800870E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# ...
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.01
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.17703683896 [6.298006560712E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.942527188777E+00
# Function: quadratic(matrix_quadratic) =  2.596344894239E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.433786132371E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.521072796935E+01  Residual=0.000000000000E+00
# Ext.iteration=131  Objective=0.117884896370E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.17884896370 [3.339395426849E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.12, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.17884896370 [3.339395426849E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.947086752481E+00
# Function: quadratic(matrix_quadratic) =  1.426271236764E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.461973658206E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.525622605364E+01  Residual=0.000000000000E+00
# Ext.iteration=147  Objective=0.122102296480E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.22102296480 [3.897944189646E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.11, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.22102296480 [3.897944189646E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  3.052493954202E+00
# Function: quadratic(matrix_quadratic) =  2.538311841701E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.488555353703E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.516139846743E+01  Residual=0.000000000000E+00
# Ext.iteration=115  Objective=0.116924086831E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16924086831 [2.782596375539E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.11, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16924086831 [2.782596375539E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.923006881015E+00
# Function: quadratic(matrix_quadratic) =  3.811590369604E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.418696503665E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.511350574713E+01  Residual=0.000000000000E+00
# Ext.iteration=120  Objective=0.111845456675E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.11845456675 [2.645883512287E-12]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.11845456675 [2.645883512287E-12]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.796088089668E+00
# Function: quadratic(matrix_quadratic) =  1.933088765668E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.391777224636E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.514607279693E+01  Residual=0.000000000000E+00
# Ext.iteration=107  Objective=0.117560871794E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.17560871794 [3.476774423916E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.17560871794 [3.476774423916E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.938938817768E+00
# Function: quadratic(matrix_quadratic) =  3.319082866018E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.467345649001E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.509578544061E+01  Residual=0.000000000000E+00
# Ext.iteration=110  Objective=0.111145770075E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.11145770075 [4.706923739661E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.11145770075 [4.706923739661E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.778607279467E+00
# Function: quadratic(matrix_quadratic) =  1.478896328708E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.374659328310E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.515613026820E+01  Residual=0.000000000000E+00
# Ext.iteration=118  Objective=0.114939657249E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.14939657249 [8.504308368629E-14]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.14939657249 [8.504308368629E-14]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.873416318405E+00
# Function: quadratic(matrix_quadratic) =  3.004512727771E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.417690808613E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.518390804598E+01  Residual=0.000000000000E+00
# Ext.iteration=129  Objective=0.116928276032E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16928276032 [2.972599943973E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16928276032 [2.972599943973E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.923158697801E+00
# Function: quadratic(matrix_quadratic) =  1.928119474715E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.427970054489E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.511733716475E+01  Residual=0.000000000000E+00
# Ext.iteration=108  Objective=0.112918814275E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.12918814275 [6.540545882672E-12]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.12918814275 [6.540545882672E-12]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.822886406603E+00
# Function: quadratic(matrix_quadratic) =  3.358011270002E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.374804230813E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.520498084291E+01  Residual=0.000000000000E+00
# Ext.iteration=120  Objective=0.119138915929E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.19138915929 [4.463933667154E-10]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.12, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.19138915929 [4.463933667154E-10]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.978408839238E+00
# Function: quadratic(matrix_quadratic) =  2.562359705311E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.466235024499E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.514128352490E+01  Residual=0.000000000000E+00
# Ext.iteration=91  Objective=0.114596830227E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.14596830227 [5.313105511107E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.02, solving_time = 0.01
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.14596830227 [5.313105511107E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.864876821446E+00
# Function: quadratic(matrix_quadratic) =  1.757368989634E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.450304081830E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.515421455939E+01  Residual=0.000000000000E+00
# Ext.iteration=111  Objective=0.115669390081E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.15669390081 [3.088640454507E-13]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.10, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.15669390081 [3.088640454507E-13]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.891702775906E+00
# Function: quadratic(matrix_quadratic) =  1.279044630402E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.435249718453E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.519636015326E+01  Residual=0.000000000000E+00
# Ext.iteration=114  Objective=0.117343290681E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.17343290681 [7.327471962526E-15]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.11, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.17343290681 [7.327471962526E-15]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.933532553643E+00
# Function: quadratic(matrix_quadratic) =  1.988535626260E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.463463354538E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.515181992337E+01  Residual=0.000000000000E+00
# Ext.iteration=113  Objective=0.117266068871E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.17266068871 [7.468914375863E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.17266068871 [7.468914375863E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.931575164896E+00
# Function: quadratic(matrix_quadratic) =  3.062275576074E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.432141632595E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.513314176245E+01  Residual=0.000000000000E+00
# Ext.iteration=116  Objective=0.113617007040E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.13617007040 [1.239008895482E-13]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.13617007040 [1.239008895482E-13]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.840383724962E+00
# Function: quadratic(matrix_quadratic) =  1.658041578811E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.419831096532E+00
# OK. Solver Finished
#
# Running solver
# Reading problem formulation
# Asking for data information
# Getting data
# 100% of abs(matrix_scenarios) was read
# 100% of matrix_quadratic was read
# Start optimization
# Ext.iteration=0  Objective=0.520977011494E+01  Residual=0.000000000000E+00
# Ext.iteration=117  Objective=0.116871403553E+01  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1.16871403553 [7.814215940982E-11]
# Solver has normally finished. Solution was saved.
# Problem: problem_1, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.01, solving_time = 0.02
# Variables: optimal_point = point_problem_1
# Objective: objective = 1.16871403553 [7.814215940982E-11]
# Function: cvar_risk(0.6,abs(matrix_scenarios)) =  2.921723695250E+00
# Function: quadratic(matrix_quadratic) =  2.455743356887E-05
# Function: var_risk(0.6,abs(matrix_scenarios)) =  1.417440723924E+00
# OK. Solver Finished

# %%
cvar_ave_coeff = [sum(col)/len(col) for col in zip(*cvar_coeff_vec)]
svr_ave_coeff = [sum(col)/len(col) for col in zip(*svr_coeff_vec)]

# %%
svr_ave_coeff
# Out:
# [0.06663225645783867,
#  0.8687068186372268,
#  0.5926547226134126,
#  3.735787346579565,
#  -3.7932459034503108,
#  -1.030707604870167,
#  1.105807893445083,
#  -0.6508626363564335,
#  0.06483302365944914]

# %%
cvar_ave_coeff
# Out:
# [0.06725650581450035,
#  0.8714386720709176,
#  0.5905901438444047,
#  3.8502966832228145,
#  -3.849507755031685,
#  -1.0591340455234934,
#  1.0717762642893147,
#  -0.6495582806691174,
#  0.06489035500052491]

# %%
cvar_ave_interp = np.mean(cvar_interp_vec)
svr_ave_interp = np.mean(svr_interp_vec)

# %%
cvar_ave_interp
# Out:
# 9.965986342499919

# %%
svr_ave_interp
# Out:
# 9.96402642088119
